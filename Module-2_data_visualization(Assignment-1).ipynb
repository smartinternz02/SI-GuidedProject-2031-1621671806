# %%
import seaborn as sns
import matplotlib.pyplot as plt#because most it utilities are used in pyplot
import numpy as np

# %%
print(sns.get_dataset_names())
# Out:
# C:\Users\91843\anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\91843\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(df.sepal_length,df.sepal_width)

# %%
sns.distplot(df.petal_length,kde=False)

# %%
sns.countplot(data=df,x="species")

# %%
sns.barplot(data=df,x="sepal_length",y="sepal_width",hue="species")

# %%
sns.jointplot(data=df,x="petal_length",y="petal_width")

# %%
sns.boxplot(x="petal_length",y="petal_width",data=df)

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")

# %%
sns.pairplot(data=df,hue="species",kind="scatter",palette="husl")
